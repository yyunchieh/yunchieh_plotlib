# %%
from yunchieh_plotlib.Plot_function import plot_boxplot
import pandas as pd
import matplotlib.pyplot as plt

# %%
from yunchieh_plotlib.Plot_function import plot_boxplot
df = pd.DataFrame({
    'column_name': [1, 2, 2, 3, 3, 3, 4, 4, 5, 5, 5, 6, 6, 7]
})

fig, ax = plt.subplots(figsize=(6, 4))
plot_boxplot(ax, df, 'column_name', 
             set_title='Boxplot Example', 
             set_xlabel='X-axis Label', 
             set_ylabel='Y-axis Label',
             set_xticks="Type",
             set_xticklabels=["Category"],
             tick_params={"labelsize": 10, "direction": "inout"})
plt.show()
